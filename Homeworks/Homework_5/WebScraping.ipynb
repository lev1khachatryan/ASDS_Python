# %%
# import bs4
# from urllib.request import urlopen as uReq
# from bs4 import BeautifulSoup as soup

# %%
# my_url ='https://www.newegg.com/Product/ProductList.aspx?Submit=ENE&DEPA=0&Order=BESTMATCH&Description=graphics+card&ignorear=0&N=-1&isNodeId=1'
# uClient = uReq(my_url)

# %%
# page_html = uClient.read()

# %%
# uClient.close()

# %%
# page_soup = soup(page_html , "html.parser")

# %%
# containers = page_soup.findAll("div", {"class" : "item-container"})

# %%
# len(containers)
# containers[0]
# Out:
# <div class="item-container ">
# <!--product image-->
# <a class="item-img" href="https://www.newegg.com/Product/Product.aspx?Item=N82E16814487290&amp;cm_re=graphics_card-_-14-487-290-_-Product">
# <img alt="EVGA GeForce GTX 1050 Ti GAMING, 04G-P4-6251-KR, 4GB GDDR5, DX12 OSD Support (PXOC)" src="//c1.neweggimages.com/ProductImageCompressAll300/14-487-290-01.jpg" title="EVGA GeForce GTX 1050 Ti GAMING, 04G-P4-6251-KR, 4GB GDDR5, DX12 OSD Support (PXOC)"/>
# </a>
# <div class="item-info">
# <!--brand info-->
# <div class="item-branding">
# <a class="item-brand" href="https://www.newegg.com/EVGA/BrandStore/ID-1402">
# <img alt="EVGA" src="//c1.neweggimages.com/Brandimage_70x28//Brand1402.gif" title="EVGA"/>
# </a>
# <!--rating info-->
# <a class="item-rating" href="https://www.newegg.com/Product/Product.aspx?Item=N82E16814487290&amp;SortField=0&amp;SummaryType=0&amp;PageSize=10&amp;SelectedRating=-1&amp;VideoOnlyMark=False&amp;ignorebbr=1&amp;IsFeedbackTab=true#scrollFullInfo" title="Rating + 5"><i class="rating rating-5"></i><span class="item-rating-num">(65)</span></a>
# </div>
# <!--description info-->
# <a class="item-title" href="https://www.newegg.com/Product/Product.aspx?Item=N82E16814487290&amp;cm_re=graphics_card-_-14-487-290-_-Product" title="View Details"><i class="icon-premier icon-premier-xsm"></i>EVGA GeForce GTX 1050 Ti GAMING, 04G-P4-6251-KR, 4GB GDDR5, DX12 OSD Support (PXOC)</a>
# <!--promption info-->
# <p class="item-promo"><i class="item-promo-icon"></i>Free 500W Power Supply w/ purchase, limited offer</p>
# <!--feature-->
# <ul class="item-features">
# <li><strong>Core Clock:</strong> 1290 MHz</li><li><strong>Max Resolution:</strong> 7680 x 4320</li><li><strong>DisplayPort:</strong> 1 x DisplayPort 1.4</li><li><strong>DVI:</strong> 1 x Dual-Link DVI-D</li>
# <li><strong>Model #: </strong>04G-P4-6251-KR</li>
# <li><strong>Item #: </strong>N82E16814487290</li>
# <li><strong>Return Policy: </strong><a href="https://kb.newegg.com/Article/Index/12/3?id=1167#80" target="_blank" title="Replacement Only Return Policy(New Window)">Replacement Only Return Policy</a></li>
# </ul>
# <div class="item-action">
# <!--price-->
# <ul class="price has-label-membership ">
# <li class="price-was">
#        $209.99
#             <span class="price-was-data" style="display: none">209.99</span>
# </li>
# <li class="price-map">
# </li>
# <li class="price-current">
# <span class="price-current-label">
# <a aria-label="Premier Price Explaination" class="membership-info membership-popup" data-neg-popid="MembershipPopup" href="javascript:void(0);" name="membership" style="display: inline"><span class="membership-icon"></span><span style="display: none">|</span></a>
# </span>$<strong>169</strong><sup>.99</sup> <a class="price-current-num" href="https://www.newegg.com/Product/Product.aspx?Item=N82E16814487290&amp;buyingoptions=New">(20 Offers)</a>
# <span class="price-current-range">
# <abbr title="to">–</abbr>
# </span>
# </li>
# <li class="price-save ">
# <span class="price-save-endtime price-save-endtime-current"></span>
# <span class="price-save-endtime price-save-endtime-another" style="display:none;"></span>
# <span class="price-save-label">Save: </span>
# <span class="price-save-dollar"></span>
# <span class="price-save-percent">19%</span>
# </li>
# <li class="price-note">
# <span class="price-note-dollar" data-price="$149.99">$149.99</span>
# <span class="price-note-label "> after </span>
# <span class="price-note-dollar">$20.00</span>
# <span class="price-note-label"> rebate card</span>
# </li>
# <li class="price-ship">
#         $4.99 Shipping
#     </li>
# </ul>
# <!--egg point-->
# <!--financing-->
# <!--button-->
# <div class="item-operate ">
# <div class="item-button-area">
# <button class="btn btn-mini " onclick="Javascript:Biz.ProductList.Item.add('https://www.newegg.com/Product/Product.aspx?Item=N82E16814487290');" title="View Details" type="button">View Details <i class="fa fa-caret-right"></i></button>
# </div>
# <!--compare-->
# <div class="item-compare-box">
# <label class="form-checkbox">
# <input aria-labelledby="CompareItem" autocomplete="off" id="CompareItem_14-487-290" name="CompareItem" neg-itemnumber="14-487-290" type="checkbox" value="CompareItem_14-487-290"/>
# <span class="form-checkbox-title">Compare</span>
# </label>
# </div>
# <script type="text/javascript">
#                         Biz.Product.CompareConfig.compareItems.push("14-487-290");
#                         var itemThumbs = new Object();
#                         itemThumbs.itemNumber = "14-487-290";
#                         itemThumbs.imageUrl = "//c1.neweggimages.com/ProductImageCompressAll35/14-487-290-01.jpg";
#                         Biz.Product.CompareConfig.Thumbs.push(itemThumbs);
#                     </script>
# </div>
# </div>
# </div>
# </div>

# %%
# container = containers[0]
# title_container = container.findAll("a", {"class" : "item-title"})
# title_container[0].text
# shipping_container = container.findAll("li", {"class" : "price-ship"})
# shipping_container[0].text.strip()

# %%
# file_name = "products.csv"
# f = open(file_name, "w")
# headers = "brand, Product_name, shipping\n"
# f.write(headers)
# for container in containers:
#     brand = container.div.div.a.img["title"]
    
#     title_container = container.findAll("a", {"class" : "item-title"})
#     product_name = title_container[0].text
    
#     shipping_container = container.findAll("li", {"class" : "price-ship"})
#     shipping = shipping_container[0].text.strip()
    
#     print("brand : " + brand)
#     print("product_name : " + product_name)
#     print("shipping : " + shipping)
    
#     f.write(brand + "," + product_name.replace(",", "|") + "," + shipping + "\n")
# #     print("")
# f.close()
# Out:
# brand : EVGA
# product_name : EVGA GeForce GTX 1050 Ti GAMING, 04G-P4-6251-KR, 4GB GDDR5, DX12 OSD Support (PXOC)
# shipping : $4.99 Shipping
# brand : Sapphire Tech
# product_name : SAPPHIRE Radeon RX Vega 64 DirectX 12 21275-03-20G 8GB 2048-Bit HBM2 PCI Express 3.0 CrossFireX Support Video Card
# shipping : $4.99 Shipping
# brand : GIGABYTE
# product_name : GIGABYTE AORUS GeForce RTX 2070 DirectX 12 GV-N2070AORUS X-8GC 8GB 256-Bit GDDR6 PCI Express 3.0 x16 ATX Video Card
# shipping : Free Shipping
# brand : MSI
# product_name : MSI GeForce GTX 1050 Ti DirectX 12 GTX 1050 Ti GAMING X 4G 4GB 128-Bit GDDR5 PCI Express 3.0 x16 HDCP Ready ATX Video Card
# shipping : $4.99 Shipping
# brand : MSI
# product_name : MSI GeForce RTX 2070 DirectX 12 RTX 2070 DUKE 8G OC 8GB 256-Bit GDDR6 PCI Express 3.0 x16 HDCP Ready Video Card
# shipping : Free Shipping
# brand : EVGA
# product_name : EVGA GeForce GTX 1060 6GB SSC GAMING ACX 3.0, 6GB GDDR5, LED, DX12 OSD Support (PXOC), 06G-P4-6267-KR
# shipping : $4.99 Shipping
# brand : GIGABYTE
# product_name : GIGABYTE AORUS GeForce RTX 2070 DirectX 12 GV-N2070AORUS-8GC 8GB 256-Bit GDDR6 PCI Express 3.0 x16 ATX Video Card
# shipping : Free Shipping
# brand : ASUS
# product_name : ASUS Dual GeForce RTX 2070 DirectX 12 DUAL-RTX2070-O8G 8GB 256-Bit GDDR6 PCI Express 3.0 HDCP Ready Video Card
# shipping : Free Shipping
# brand : GIGABYTE
# product_name : GIGABYTE AORUS GeForce RTX 2080 8GB Video Card with RGB, GV-N2080AORUS-8GC
# shipping : Free Shipping
# brand : PowerColor
# product_name : PowerColor Red Dragon Radeon RX 560 14CU DirectX 12 AXRX 560 4GBD5-DHA 4GB 128-Bit GDDR5 PCI Express 3.0 CrossFireX Support ATX Video Card
# shipping : $3.99 Shipping
# brand : Sapphire Tech
# product_name : Sapphire PULSE Radeon RX 580 8GB GDDR5 PCI-E Dual HDMI / DVI-D / Dual DP OC w/ Backplate (UEFI), 100411P8GOCL
# shipping : $4.99 Shipping
# brand : EVGA
# product_name : EVGA GeForce GTX 1050 Ti FTW GAMING ACX 3.0, 04G-P4-6258-KR, 4GB GDDR5, DX12 OSD Support (PXOC)
# shipping : Free Shipping
# brand : MSI
# product_name : MSI GeForce GTX 1060 DirectX 12 GTX 1060 GAMING X 6G 6GB 192-Bit GDDR5 PCI Express 3.0 x16 HDCP Ready ATX Video Card
# shipping : $4.99 Shipping
# brand : MSI
# product_name : MSI GeForce RTX 2080 DirectX 12 RTX 2080 SEA HAWK X 8GB 256-Bit GDDR6 PCI Express 3.0 x16 HDCP Ready SLI Support Video Card
# shipping : Free Shipping
# brand : EVGA
# product_name : EVGA GeForce GTX 1070 SC GAMING ACX 3.0 Black Edition, 08G-P4-5173-KR, 8GB GDDR5, LED, DX12 OSD Support (PXOC)
# shipping : Free Shipping
# brand : MSI
# product_name : MSI GeForce RTX 2080 GAMING X TRIO Video Card
# shipping : Free Shipping
# brand : GIGABYTE
# product_name : GIGABYTE GeForce GTX 1060 DirectX 12 GV-N1060WF2OC-6GD 6GB 192-Bit GDDR5 PCI Express 3.0 x16 ATX Video Card
# shipping : $4.99 Shipping
# brand : ZOTAC
# product_name : ZOTAC GeForce GTX 1080 Ti AMP Edition 11GB GDDR5X 352-bit Gaming Graphics Card VR Ready 16+2 Power Phase Freeze Fan Stop IceStorm Cooling Spectra Lighting ZT-P10810D-10P
# shipping : $4.99 Shipping
# brand : GIGABYTE
# product_name : GIGABYTE GeForce GTX 1050 DirectX 12 GV-N1050OC-2GD 2GB 128-Bit GDDR5 PCI Express 3.0 x16 ATX Video Card
# shipping : $4.99 Shipping
# brand : GIGABYTE
# product_name : GIGABYTE GeForce GTX 1080 Ti DirectX 12 GV-N108TGAMING OC-11GD 11GB 352-Bit GDDR5X PCI Express 3.0 x16 ATX Video Card
# shipping : $4.99 Shipping
# brand : EVGA
# product_name : EVGA GeForce GTX 1050 GAMING, 02G-P4-6150-KR, 2GB GDDR5, DX12 OSD Support (PXOC)
# shipping : $4.99 Shipping
# brand : GIGABYTE
# product_name : GIGABYTE GeForce GTX 1060 DirectX 12 GV-N1060D5-6GD REV2 6GB 192-Bit GDDR5 PCI Express 3.0 x16 ATX Video Card
# shipping : $4.99 Shipping
# brand : MSI
# product_name : MSI GeForce GTX 1070 DirectX 12 GTX 1070 ARMOR 8G OC 8GB 256-Bit GDDR5 PCI Express 3.0 x16 HDCP Ready SLI Support ATX Video Card
# shipping : $4.99 Shipping
# brand : MSI
# product_name : MSI GeForce RTX 2070 DirectX 12 RTX 2070 GAMING Z 8G 8GB 256-Bit GDDR6 PCI Express 3.0 x16 HDCP Ready Video Card
# shipping : Free Shipping
# brand : PowerColor
# product_name : PowerColor RED DRAGON Radeon RX 570 DirectX 12 AXRX 570 4GBD5-3DHD/OC 4GB 256-Bit GDDR5 PCI Express 3.0 CrossFireX Support ATX Video Card
# shipping : $4.99 Shipping
# brand : EVGA
# product_name : EVGA GeForce GTX 1050 Ti SC GAMING, 04G-P4-6253-KR, 4GB GDDR5, DX12 OSD Support (PXOC)
# shipping : $4.99 Shipping
# brand : MSI
# product_name : MSI GeForce GTX 1080 DirectX 12 GTX 1080 GAMING X 8G 8GB 256-Bit GDDR5X PCI Express 3.0 x16 HDCP Ready SLI Support ATX Video Card
# shipping : $4.99 Shipping
# brand : EVGA
# product_name : EVGA GeForce GTX 1060 SC GAMING, ACX 2.0 (Single Fan), 06G-P4-6163-KR, 6GB GDDR5, DX12 OSD Support (PXOC), Only 6.8 Inches
# shipping : $4.99 Shipping
# brand : MSI
# product_name : MSI Radeon RX 580 DirectX 12 RX 580 ARMOR 8G OC 8GB 256-Bit GDDR5 PCI Express x16 HDCP Ready CrossFireX Support Video Card
# shipping : $3.99 Shipping
# brand : MSI
# product_name : MSI Radeon RX 580 DirectX 12 Radeon RX 580 8G V1 8GB 256-Bit GDDR5 PCI Express x16 HDCP Ready CrossFireX Support Video Card
# shipping : Free Shipping
# brand : MSI
# product_name : MSI GeForce GTX 1080 DirectX 12 GTX 1080 DUKE 8G OC 8GB 256-Bit GDDR5X PCI Express 3.0 x16 HDCP Ready SLI Support Video Cards
# shipping : Free Shipping
# brand : GIGABYTE
# product_name : GIGABYTE Radeon RX 580 DirectX 12 GV-RX580GAMING-8GD 8GB 256-Bit GDDR5 PCI Express 3.0 x16 ATX Video Card
# shipping : $4.99 Shipping
# brand : MSI
# product_name : MSI GeForce GTX 1080 DirectX 12 GTX 1080 GAMING 8G 8GB 256-Bit GDDR5X PCI Express 3.0 x16 HDCP Ready SLI Support ATX Video Card
# shipping : Free Shipping
# brand : EVGA
# product_name : EVGA GeForce RTX 2070 XC GAMING, 08G-P4-2172-KR, 8GB GDDR6, Dual HDB Fans & RGB LED
# shipping : Free Shipping
# brand : EVGA
# product_name : EVGA GeForce GTX 1060 DirectX 12 06G-P4-6262-KR 6GB 192-Bit GDDR5 PCI Express 3.0 Video Card
# shipping : $4.99 Shipping
# brand : GIGABYTE
# product_name : GIGABYTE GeForce GTX 1070 Ti DirectX 12 GV-N107TGAMING-8GD 8GB 256-Bit GDDR5 PCI Express 3.0 x16 SLI Support ATX Video Card
# shipping : Free Shipping

# %%
import numpy as np
import pandas as pd
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

my_url ='https://www.newegg.com/Product/ProductList.aspx?Submit=ENE&DEPA=0&Order=BESTMATCH&Description=graphics+card&ignorear=0&N=-1&isNodeId=1'
uClient = uReq(my_url)

page_html = uClient.read()
uClient.close()
page_soup = soup(page_html , "html.parser")
containers = page_soup.findAll("div", {"class" : "item-container"})

file_name = "products.csv"
f = open(file_name, "w")
headers = "brand, Product_name, shipping\n"
f.write(headers)
for container in containers:
    brand = container.div.div.a.img["title"]
    
    title_container = container.findAll("a", {"class" : "item-title"})
    product_name = title_container[0].text
    
    shipping_container = container.findAll("li", {"class" : "price-ship"})
    shipping = shipping_container[0].text.strip()
    
#     print("brand : " + brand)
#     print("product_name : " + product_name)
#     print("shipping : " + shipping)
#     print("")
    
    f.write(brand + "," + product_name.replace(",", "|") + "," + shipping + "\n")
f.close()

train_df = pd.read_csv("products.csv")
# Out:
# (36, 3)

# %%
train_df
# Out:
#             brand                                       Product_name  \
# 0            EVGA  EVGA GeForce GTX 1050 Ti GAMING| 04G-P4-6251-K...
# 1   Sapphire Tech  SAPPHIRE Radeon RX Vega 64 DirectX 12 21275-03...
# 2        GIGABYTE  GIGABYTE AORUS GeForce RTX 2070 DirectX 12 GV-...
# 3             MSI  MSI GeForce GTX 1050 Ti DirectX 12 GTX 1050 Ti...
# 4             MSI  MSI GeForce RTX 2070 DirectX 12 RTX 2070 DUKE ...
# 5            EVGA  EVGA GeForce GTX 1060 6GB SSC GAMING ACX 3.0| ...
# 6        GIGABYTE  GIGABYTE AORUS GeForce RTX 2070 DirectX 12 GV-...
# 7            ASUS  ASUS Dual GeForce RTX 2070 DirectX 12 DUAL-RTX...
# 8        GIGABYTE  GIGABYTE AORUS GeForce RTX 2080 8GB Video Card...
# 9      PowerColor  PowerColor Red Dragon Radeon RX 560 14CU Direc...
# 10  Sapphire Tech  Sapphire PULSE Radeon RX 580 8GB GDDR5 PCI-E D...
# 11           EVGA  EVGA GeForce GTX 1050 Ti FTW GAMING ACX 3.0| 0...
# 12            MSI  MSI GeForce GTX 1060 DirectX 12 GTX 1060 GAMIN...
# 13            MSI  MSI GeForce RTX 2080 DirectX 12 RTX 2080 SEA H...
# 14           EVGA  EVGA GeForce GTX 1070 SC GAMING ACX 3.0 Black ...
# 15            MSI      MSI GeForce RTX 2080 GAMING X TRIO Video Card
# 16       GIGABYTE  GIGABYTE GeForce GTX 1060 DirectX 12 GV-N1060W...
# 17          ZOTAC  ZOTAC GeForce GTX 1080 Ti AMP Edition 11GB GDD...
# 18       GIGABYTE  GIGABYTE GeForce GTX 1050 DirectX 12 GV-N1050O...
# 19       GIGABYTE  GIGABYTE GeForce GTX 1080 Ti DirectX 12 GV-N10...
# 20           EVGA  EVGA GeForce GTX 1050 GAMING| 02G-P4-6150-KR| ...
# 21       GIGABYTE  GIGABYTE GeForce GTX 1060 DirectX 12 GV-N1060D...
# 22            MSI  MSI GeForce GTX 1070 DirectX 12 GTX 1070 ARMOR...
# 23            MSI  MSI GeForce RTX 2070 DirectX 12 RTX 2070 GAMIN...
# 24     PowerColor  PowerColor RED DRAGON Radeon RX 570 DirectX 12...
# 25           EVGA  EVGA GeForce GTX 1050 Ti SC GAMING| 04G-P4-625...
# 26            MSI  MSI GeForce GTX 1080 DirectX 12 GTX 1080 GAMIN...
# 27           EVGA  EVGA GeForce GTX 1060 SC GAMING| ACX 2.0 (Sing...
# 28            MSI  MSI Radeon RX 580 DirectX 12 RX 580 ARMOR 8G O...
# 29            MSI  MSI Radeon RX 580 DirectX 12 Radeon RX 580 8G ...
# 30            MSI  MSI GeForce GTX 1080 DirectX 12 GTX 1080 DUKE ...
# 31       GIGABYTE  GIGABYTE Radeon RX 580 DirectX 12 GV-RX580GAMI...
# 32            MSI  MSI GeForce GTX 1080 DirectX 12 GTX 1080 GAMIN...
# 33           EVGA  EVGA GeForce RTX 2070 XC GAMING| 08G-P4-2172-K...
# 34           EVGA  EVGA GeForce GTX 1060 DirectX 12 06G-P4-6262-K...
# 35       GIGABYTE  GIGABYTE GeForce GTX 1070 Ti DirectX 12 GV-N10...
#
#           shipping
# 0   $4.99 Shipping
# 1   $4.99 Shipping
# 2    Free Shipping
# 3   $4.99 Shipping
# 4    Free Shipping
# 5   $4.99 Shipping
# 6    Free Shipping
# 7    Free Shipping
# 8    Free Shipping
# 9   $3.99 Shipping
# 10  $4.99 Shipping
# 11   Free Shipping
# 12  $4.99 Shipping
# 13   Free Shipping
# 14   Free Shipping
# 15   Free Shipping
# 16  $4.99 Shipping
# 17  $4.99 Shipping
# 18  $4.99 Shipping
# 19  $4.99 Shipping
# 20  $4.99 Shipping
# 21  $4.99 Shipping
# 22  $4.99 Shipping
# 23   Free Shipping
# 24  $4.99 Shipping
# 25  $4.99 Shipping
# 26  $4.99 Shipping
# 27  $4.99 Shipping
# 28  $3.99 Shipping
# 29   Free Shipping
# 30   Free Shipping
# 31  $4.99 Shipping
# 32   Free Shipping
# 33   Free Shipping
# 34  $4.99 Shipping
# 35   Free Shipping
